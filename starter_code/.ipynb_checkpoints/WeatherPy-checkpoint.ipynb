# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

import math
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = '../output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?q='

citySets = np.array_split(cities, math.ceil(len(cities)/40))
cityData = []
sCount = 0
errCount = 0

print('Beginning Data Retrieval\n-----------------------------')

for citySet in citySets:
    rCount = 0
    sCount = sCount + 1
    
    for city in citySet:
        rCount = rCount + 1
        try:
            print(f'Processing Reccord {rCount} of Set {sCount} | {city}')
            response = requests.get(f'{url}{city}&appid={weather_api_key}')
            response.raise_for_status()
            
        except requests.HTTPError as exception:
            errCount = errCount + 1
            print(f'City, {city}, NOT found. Skipping...')
            continue
        
        cityData.append(response.json())

print(f'-----------------------------\nData Retrieval Complete.\nFound {len(cityData)}Records from {len(cities)} cities.\n{errCount} cities not found')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Reccord 1 of Set 1 | soyo
# Processing Reccord 2 of Set 1 | ribeira grande
# Processing Reccord 3 of Set 1 | provideniya
# Processing Reccord 4 of Set 1 | hvolsvollur
# Processing Reccord 5 of Set 1 | vila franca do campo
# Processing Reccord 6 of Set 1 | illoqqortoormiut
# City, illoqqortoormiut, NOT found. Skipping...
# Processing Reccord 7 of Set 1 | kapaa
# Processing Reccord 8 of Set 1 | dikson
# Processing Reccord 9 of Set 1 | amderma
# City, amderma, NOT found. Skipping...
# Processing Reccord 10 of Set 1 | saskylakh
# Processing Reccord 11 of Set 1 | busselton
# Processing Reccord 12 of Set 1 | hithadhoo
# Processing Reccord 13 of Set 1 | nizwa
# Processing Reccord 14 of Set 1 | paracuru
# Processing Reccord 15 of Set 1 | lebu
# Processing Reccord 16 of Set 1 | rikitea
# Processing Reccord 17 of Set 1 | severo-kurilsk
# Processing Reccord 18 of Set 1 | winton
# Processing Reccord 19 of Set 1 | buraydah
# Processing Reccord 20 of Set 1 | suntar
# Processing Reccord 21 of Set 1 | sampit
# Processing Reccord 22 of Set 1 | bredasdorp
# Processing Reccord 23 of Set 1 | punta arenas
# Processing Reccord 24 of Set 1 | chuy
# Processing Reccord 25 of Set 1 | new norfolk
# Processing Reccord 26 of Set 1 | hermanus
# Processing Reccord 27 of Set 1 | east london
# Processing Reccord 28 of Set 1 | morro bay
# Processing Reccord 29 of Set 1 | avarua
# Processing Reccord 30 of Set 1 | kavieng
# Processing Reccord 31 of Set 1 | makakilo city
# Processing Reccord 32 of Set 1 | pevek
# Processing Reccord 33 of Set 1 | belushya guba
# City, belushya guba, NOT found. Skipping...
# Processing Reccord 34 of Set 1 | isangel
# Processing Reccord 35 of Set 1 | narsaq
# Processing Reccord 36 of Set 1 | puerto asis
# Processing Reccord 37 of Set 1 | ushuaia
# Processing Reccord 38 of Set 1 | aksarayskiy
# Processing Reccord 1 of Set 2 | coquimbo
# Processing Reccord 2 of Set 2 | chiungutwa
# Processing Reccord 3 of Set 2 | bandarbeyla
# Processing Reccord 4 of Set 2 | georgetown
# Processing Reccord 5 of Set 2 | caravelas
# Processing Reccord 6 of Set 2 | taolanaro
# City, taolanaro, NOT found. Skipping...
# Processing Reccord 7 of Set 2 | tuktoyaktuk
# Processing Reccord 8 of Set 2 | vaitupu
# City, vaitupu, NOT found. Skipping...
# Processing Reccord 9 of Set 2 | hazorasp
# Processing Reccord 10 of Set 2 | puerto ayora
# Processing Reccord 11 of Set 2 | tongliao
# Processing Reccord 12 of Set 2 | belmopan
# Processing Reccord 13 of Set 2 | oromocto
# Processing Reccord 14 of Set 2 | bossembele
# City, bossembele, NOT found. Skipping...
# Processing Reccord 15 of Set 2 | humaita
# Processing Reccord 16 of Set 2 | tasiilaq
# Processing Reccord 17 of Set 2 | hobart
# Processing Reccord 18 of Set 2 | cape town
# Processing Reccord 19 of Set 2 | salym
# Processing Reccord 20 of Set 2 | namibe
# Processing Reccord 21 of Set 2 | peniche
# Processing Reccord 22 of Set 2 | san jose
# Processing Reccord 23 of Set 2 | khatanga
# Processing Reccord 24 of Set 2 | vardo
# Processing Reccord 25 of Set 2 | victoria
# Processing Reccord 26 of Set 2 | bolungarvik
# City, bolungarvik, NOT found. Skipping...
# Processing Reccord 27 of Set 2 | jamestown
# Processing Reccord 28 of Set 2 | castro
# Processing Reccord 29 of Set 2 | marienburg
# Processing Reccord 30 of Set 2 | port alfred
# Processing Reccord 31 of Set 2 | bandundu
# Processing Reccord 32 of Set 2 | andenes
# Processing Reccord 33 of Set 2 | lorengau
# Processing Reccord 34 of Set 2 | port hardy
# Processing Reccord 35 of Set 2 | mataura
# Processing Reccord 36 of Set 2 | kodiak
# Processing Reccord 37 of Set 2 | esperance
# Processing Reccord 38 of Set 2 | grants pass
# Processing Reccord 1 of Set 3 | vaini
# Processing Reccord 2 of Set 3 | pisco
# Processing Reccord 3 of Set 3 | kutum
# Processing Reccord 4 of Set 3 | sesimbra
# Processing Reccord 5 of Set 3 | bengkulu
# Processing Reccord 6 of Set 3 | albany
# Processing Reccord 7 of Set 3 | bonito
# Processing Reccord 8 of Set 3 | tiksi
# Processing Reccord 9 of Set 3 | iwanai
# Processing Reccord 10 of Set 3 | gat
# Processing Reccord 11 of Set 3 | saint-joseph
# Processing Reccord 12 of Set 3 | petatlan
# Processing Reccord 13 of Set 3 | kahului
# Processing Reccord 14 of Set 3 | san patricio
# Processing Reccord 15 of Set 3 | barentsburg
# City, barentsburg, NOT found. Skipping...
# Processing Reccord 16 of Set 3 | pavia
# Processing Reccord 17 of Set 3 | sataua
# City, sataua, NOT found. Skipping...
# Processing Reccord 18 of Set 3 | pedara
# Processing Reccord 19 of Set 3 | saint-philippe
# Processing Reccord 20 of Set 3 | barrow
# Processing Reccord 21 of Set 3 | la ronge
# Processing Reccord 22 of Set 3 | srednekolymsk
# Processing Reccord 23 of Set 3 | jahanabad
# Processing Reccord 24 of Set 3 | vestmannaeyjar
# Processing Reccord 25 of Set 3 | manokwari
# Processing Reccord 26 of Set 3 | saleaula
# City, saleaula, NOT found. Skipping...
# Processing Reccord 27 of Set 3 | northam
# Processing Reccord 28 of Set 3 | nikolskoye
# Processing Reccord 29 of Set 3 | alekseyevka
# Processing Reccord 30 of Set 3 | state college
# Processing Reccord 31 of Set 3 | palabuhanratu
# City, palabuhanratu, NOT found. Skipping...
# Processing Reccord 32 of Set 3 | cidreira
# Processing Reccord 33 of Set 3 | coos bay
# Processing Reccord 34 of Set 3 | fortuna
# Processing Reccord 35 of Set 3 | asau
# Processing Reccord 36 of Set 3 | biak
# Processing Reccord 37 of Set 3 | fort nelson
# Processing Reccord 38 of Set 3 | muroto
# Processing Reccord 1 of Set 4 | katsuura
# Processing Reccord 2 of Set 4 | batagay-alyta
# Processing Reccord 3 of Set 4 | kaitangata
# Processing Reccord 4 of Set 4 | simplicio mendes
# Processing Reccord 5 of Set 4 | bluff
# Processing Reccord 6 of Set 4 | itarema
# Processing Reccord 7 of Set 4 | kaoma
# Processing Reccord 8 of Set 4 | klaksvik
# Processing Reccord 9 of Set 4 | wulanhaote
# City, wulanhaote, NOT found. Skipping...
# Processing Reccord 10 of Set 4 | constitucion
# Processing Reccord 11 of Set 4 | phan thiet
# Processing Reccord 12 of Set 4 | saint-francois
# Processing Reccord 13 of Set 4 | vostok
# Processing Reccord 14 of Set 4 | mar del plata
# Processing Reccord 15 of Set 4 | villa carlos paz
# Processing Reccord 16 of Set 4 | airai
# Processing Reccord 17 of Set 4 | karla
# Processing Reccord 18 of Set 4 | upernavik
# Processing Reccord 19 of Set 4 | hasaki
# Processing Reccord 20 of Set 4 | qaanaaq
# Processing Reccord 21 of Set 4 | codrington
# Processing Reccord 22 of Set 4 | patacamaya
# Processing Reccord 23 of Set 4 | grand river south east
# City, grand river south east, NOT found. Skipping...
# Processing Reccord 24 of Set 4 | longyearbyen
# Processing Reccord 25 of Set 4 | sao filipe
# Processing Reccord 26 of Set 4 | betioky
# Processing Reccord 27 of Set 4 | fort saint john
# City, fort saint john, NOT found. Skipping...
# Processing Reccord 28 of Set 4 | ixtapa
# Processing Reccord 29 of Set 4 | yatou
# Processing Reccord 30 of Set 4 | cabo san lucas
# Processing Reccord 31 of Set 4 | saldanha
# Processing Reccord 32 of Set 4 | oktyabrskiy
# Processing Reccord 33 of Set 4 | carnarvon
# Processing Reccord 34 of Set 4 | ponta do sol
# Processing Reccord 35 of Set 4 | mys shmidta
# City, mys shmidta, NOT found. Skipping...
# Processing Reccord 36 of Set 4 | yellowknife
# Processing Reccord 37 of Set 4 | bereda
# Processing Reccord 38 of Set 4 | saint-pierre
# Processing Reccord 1 of Set 5 | thompson
# Processing Reccord 2 of Set 5 | shwebo
# Processing Reccord 3 of Set 5 | jackson
# Processing Reccord 4 of Set 5 | haines junction
# Processing Reccord 5 of Set 5 | dakar
# Processing Reccord 6 of Set 5 | zhigansk
# Processing Reccord 7 of Set 5 | acari
# Processing Reccord 8 of Set 5 | butaritari
# Processing Reccord 9 of Set 5 | yulara
# Processing Reccord 10 of Set 5 | sabang
# Processing Reccord 11 of Set 5 | hami
# Processing Reccord 12 of Set 5 | faya
# Processing Reccord 13 of Set 5 | shingu
# Processing Reccord 14 of Set 5 | sitka
# Processing Reccord 15 of Set 5 | safwah
# City, safwah, NOT found. Skipping...
# Processing Reccord 16 of Set 5 | mayo
# Processing Reccord 17 of Set 5 | kharsawan
# Processing Reccord 18 of Set 5 | san andres
# Processing Reccord 19 of Set 5 | tumannyy
# City, tumannyy, NOT found. Skipping...
# Processing Reccord 20 of Set 5 | kyzyl-suu
# Processing Reccord 21 of Set 5 | iqaluit
# Processing Reccord 22 of Set 5 | hofn
# Processing Reccord 23 of Set 5 | san juan
# Processing Reccord 24 of Set 5 | touros
# Processing Reccord 25 of Set 5 | tsihombe
# City, tsihombe, NOT found. Skipping...
# Processing Reccord 26 of Set 5 | honiara
# Processing Reccord 27 of Set 5 | bethel
# Processing Reccord 28 of Set 5 | byron bay
# Processing Reccord 29 of Set 5 | mweka
# Processing Reccord 30 of Set 5 | kabo
# Processing Reccord 31 of Set 5 | tuatapere
# Processing Reccord 32 of Set 5 | frankenberg
# Processing Reccord 33 of Set 5 | puerto escondido
# Processing Reccord 34 of Set 5 | pangnirtung
# Processing Reccord 35 of Set 5 | ardistan
# City, ardistan, NOT found. Skipping...
# Processing Reccord 36 of Set 5 | pacific grove
# Processing Reccord 37 of Set 5 | freeport
# Processing Reccord 38 of Set 5 | berlevag
# Processing Reccord 1 of Set 6 | antofagasta
# Processing Reccord 2 of Set 6 | kangaatsiaq
# Processing Reccord 3 of Set 6 | north bend
# Processing Reccord 4 of Set 6 | bridlington
# Processing Reccord 5 of Set 6 | selma
# Processing Reccord 6 of Set 6 | bere
# Processing Reccord 7 of Set 6 | dhangadhi
# Processing Reccord 8 of Set 6 | viedma
# Processing Reccord 9 of Set 6 | geraldton
# Processing Reccord 10 of Set 6 | saint-denis
# Processing Reccord 11 of Set 6 | paso de los toros
# Processing Reccord 12 of Set 6 | keflavik
# Processing Reccord 13 of Set 6 | lolua
# City, lolua, NOT found. Skipping...
# Processing Reccord 14 of Set 6 | solnechnyy
# Processing Reccord 15 of Set 6 | dunmore east
# Processing Reccord 16 of Set 6 | walvis bay
# Processing Reccord 17 of Set 6 | bhigvan
# Processing Reccord 18 of Set 6 | sorland
# Processing Reccord 19 of Set 6 | itapema
# Processing Reccord 20 of Set 6 | khonuu
# City, khonuu, NOT found. Skipping...
# Processing Reccord 21 of Set 6 | celestun
# Processing Reccord 22 of Set 6 | san quintin
# Processing Reccord 23 of Set 6 | harper
# Processing Reccord 24 of Set 6 | villanueva
# Processing Reccord 25 of Set 6 | taoudenni
# Processing Reccord 26 of Set 6 | kruisfontein
# Processing Reccord 27 of Set 6 | vao
# Processing Reccord 28 of Set 6 | arraial do cabo
# Processing Reccord 29 of Set 6 | kloulklubed
# Processing Reccord 30 of Set 6 | puro
# Processing Reccord 31 of Set 6 | karaul
# City, karaul, NOT found. Skipping...
# Processing Reccord 32 of Set 6 | bambous virieux
# Processing Reccord 33 of Set 6 | bridgetown
# Processing Reccord 34 of Set 6 | mecca
# Processing Reccord 35 of Set 6 | gouloure
# Processing Reccord 36 of Set 6 | dingle
# Processing Reccord 37 of Set 6 | kosino
# Processing Reccord 38 of Set 6 | sovetskiy
# Processing Reccord 1 of Set 7 | iralaya
# Processing Reccord 2 of Set 7 | cap malheureux
# Processing Reccord 3 of Set 7 | akureyri
# Processing Reccord 4 of Set 7 | ryotsu
# Processing Reccord 5 of Set 7 | atuona
# Processing Reccord 6 of Set 7 | sinazongwe
# Processing Reccord 7 of Set 7 | marsh harbour
# Processing Reccord 8 of Set 7 | san carlos de bariloche
# Processing Reccord 9 of Set 7 | jessheim
# Processing Reccord 10 of Set 7 | ofunato
# Processing Reccord 11 of Set 7 | tabiauea
# City, tabiauea, NOT found. Skipping...
# Processing Reccord 12 of Set 7 | ayagoz
# Processing Reccord 13 of Set 7 | urucara
# Processing Reccord 14 of Set 7 | shelburne
# Processing Reccord 15 of Set 7 | paamiut
# Processing Reccord 16 of Set 7 | olafsvik
# Processing Reccord 17 of Set 7 | belousovka
# Processing Reccord 18 of Set 7 | marzuq
# Processing Reccord 19 of Set 7 | ilulissat
# Processing Reccord 20 of Set 7 | santiago del estero
# Processing Reccord 21 of Set 7 | nyon
# Processing Reccord 22 of Set 7 | jibuti
# Processing Reccord 23 of Set 7 | araouane
# Processing Reccord 24 of Set 7 | tautira
# Processing Reccord 25 of Set 7 | kondoa
# Processing Reccord 26 of Set 7 | agua dulce
# Processing Reccord 27 of Set 7 | binzhou
# Processing Reccord 28 of Set 7 | samarai
# Processing Reccord 29 of Set 7 | koutiala
# Processing Reccord 30 of Set 7 | yomitan
# City, yomitan, NOT found. Skipping...
# Processing Reccord 31 of Set 7 | norman wells
# Processing Reccord 32 of Set 7 | quatre cocos
# Processing Reccord 33 of Set 7 | clyde river
# Processing Reccord 34 of Set 7 | joshimath
# Processing Reccord 35 of Set 7 | portland
# Processing Reccord 36 of Set 7 | lerwick
# Processing Reccord 37 of Set 7 | inhambane
# Processing Reccord 38 of Set 7 | torbay
# Processing Reccord 1 of Set 8 | papara
# Processing Reccord 2 of Set 8 | pontianak
# Processing Reccord 3 of Set 8 | antalaha
# Processing Reccord 4 of Set 8 | hai duong
# Processing Reccord 5 of Set 8 | ao luk
# City, ao luk, NOT found. Skipping...
# Processing Reccord 6 of Set 8 | riyadh
# Processing Reccord 7 of Set 8 | montepuez
# Processing Reccord 8 of Set 8 | verkhnyaya inta
# Processing Reccord 9 of Set 8 | deer lake
# Processing Reccord 10 of Set 8 | grand gaube
# Processing Reccord 11 of Set 8 | lenger
# Processing Reccord 12 of Set 8 | wajima
# Processing Reccord 13 of Set 8 | chapais
# Processing Reccord 14 of Set 8 | samusu
# City, samusu, NOT found. Skipping...
# Processing Reccord 15 of Set 8 | axim
# Processing Reccord 16 of Set 8 | coihaique
# Processing Reccord 17 of Set 8 | troitskoye
# Processing Reccord 18 of Set 8 | aldan
# Processing Reccord 19 of Set 8 | chokurdakh
# Processing Reccord 20 of Set 8 | ponta delgada
# Processing Reccord 21 of Set 8 | port elizabeth
# Processing Reccord 22 of Set 8 | amga
# Processing Reccord 23 of Set 8 | gazli
# Processing Reccord 24 of Set 8 | yaan
# Processing Reccord 25 of Set 8 | asfi
# Processing Reccord 26 of Set 8 | kieta
# Processing Reccord 27 of Set 8 | faanui
# Processing Reccord 28 of Set 8 | vaitape
# Processing Reccord 29 of Set 8 | port said
# Processing Reccord 30 of Set 8 | muravlenko
# Processing Reccord 31 of Set 8 | sentyabrskiy
# City, sentyabrskiy, NOT found. Skipping...
# Processing Reccord 32 of Set 8 | camana
# Processing Reccord 33 of Set 8 | korla
# Processing Reccord 34 of Set 8 | morrope
# Processing Reccord 35 of Set 8 | ewo
# Processing Reccord 36 of Set 8 | talnakh
# Processing Reccord 37 of Set 8 | mahibadhoo
# Processing Reccord 38 of Set 8 | ciro marina
# Processing Reccord 1 of Set 9 | wanning
# Processing Reccord 2 of Set 9 | port-cartier
# Processing Reccord 3 of Set 9 | maracaju
# Processing Reccord 4 of Set 9 | sterling
# Processing Reccord 5 of Set 9 | abu jubayhah
# City, abu jubayhah, NOT found. Skipping...
# Processing Reccord 6 of Set 9 | bonavista
# Processing Reccord 7 of Set 9 | kanniyakumari
# Processing Reccord 8 of Set 9 | gijon
# Processing Reccord 9 of Set 9 | matamoros
# Processing Reccord 10 of Set 9 | murud
# Processing Reccord 11 of Set 9 | kerman
# Processing Reccord 12 of Set 9 | stornoway
# Processing Reccord 13 of Set 9 | attawapiskat
# City, attawapiskat, NOT found. Skipping...
# Processing Reccord 14 of Set 9 | aquidauana
# Processing Reccord 15 of Set 9 | xuddur
# Processing Reccord 16 of Set 9 | richards bay
# Processing Reccord 17 of Set 9 | ilebo
# Processing Reccord 18 of Set 9 | rawson
# Processing Reccord 19 of Set 9 | higuey
# City, higuey, NOT found. Skipping...
# Processing Reccord 20 of Set 9 | moletai
# Processing Reccord 21 of Set 9 | esna
# Processing Reccord 22 of Set 9 | tunga
# Processing Reccord 23 of Set 9 | namatanai
# Processing Reccord 24 of Set 9 | baoding
# Processing Reccord 25 of Set 9 | tougue
# Processing Reccord 26 of Set 9 | bargal
# City, bargal, NOT found. Skipping...
# Processing Reccord 27 of Set 9 | olga
# Processing Reccord 28 of Set 9 | pafos
# Processing Reccord 29 of Set 9 | pozhva
# Processing Reccord 30 of Set 9 | champerico
# Processing Reccord 31 of Set 9 | port lincoln
# Processing Reccord 32 of Set 9 | neepawa
# Processing Reccord 33 of Set 9 | mount isa
# Processing Reccord 34 of Set 9 | gueret
# Processing Reccord 35 of Set 9 | saint george
# Processing Reccord 36 of Set 9 | linhares
# Processing Reccord 37 of Set 9 | aklavik
# Processing Reccord 38 of Set 9 | aguimes
# Processing Reccord 1 of Set 10 | eydhafushi
# Processing Reccord 2 of Set 10 | carnduff
# Processing Reccord 3 of Set 10 | calama
# Processing Reccord 4 of Set 10 | chumikan
# Processing Reccord 5 of Set 10 | yelovo
# Processing Reccord 6 of Set 10 | manitouwadge
# Processing Reccord 7 of Set 10 | comodoro rivadavia
# Processing Reccord 8 of Set 10 | flinders
# Processing Reccord 9 of Set 10 | seminole
# Processing Reccord 10 of Set 10 | ormara
# Processing Reccord 11 of Set 10 | zhanatas
# City, zhanatas, NOT found. Skipping...
# Processing Reccord 12 of Set 10 | oksfjord
# Processing Reccord 13 of Set 10 | hawalli
# Processing Reccord 14 of Set 10 | mapiripan
# Processing Reccord 15 of Set 10 | yei
# Processing Reccord 16 of Set 10 | kodinar
# Processing Reccord 17 of Set 10 | darhan
# Processing Reccord 18 of Set 10 | nikolayevsk-na-amure
# Processing Reccord 19 of Set 10 | labuhan
# Processing Reccord 20 of Set 10 | tarakan
# Processing Reccord 21 of Set 10 | sao felix do xingu
# Processing Reccord 22 of Set 10 | cururupu
# Processing Reccord 23 of Set 10 | tynda
# Processing Reccord 24 of Set 10 | nabire
# Processing Reccord 25 of Set 10 | martaban
# Processing Reccord 26 of Set 10 | kavaratti
# Processing Reccord 27 of Set 10 | paternion
# Processing Reccord 28 of Set 10 | todos santos
# Processing Reccord 29 of Set 10 | lingao
# Processing Reccord 30 of Set 10 | sikasso
# Processing Reccord 31 of Set 10 | nhulunbuy
# Processing Reccord 32 of Set 10 | praia
# Processing Reccord 33 of Set 10 | lagoa
# Processing Reccord 34 of Set 10 | oskaloosa
# Processing Reccord 35 of Set 10 | zarand
# Processing Reccord 36 of Set 10 | belmonte
# Processing Reccord 37 of Set 10 | rock island
# Processing Reccord 38 of Set 10 | port blair
# Processing Reccord 1 of Set 11 | cherskiy
# Processing Reccord 2 of Set 11 | kayerkan
# Processing Reccord 3 of Set 11 | berbera
# Processing Reccord 4 of Set 11 | meulaboh
# Processing Reccord 5 of Set 11 | sept-iles
# Processing Reccord 6 of Set 11 | sao jose da coroa grande
# Processing Reccord 7 of Set 11 | ngukurr
# City, ngukurr, NOT found. Skipping...
# Processing Reccord 8 of Set 11 | necochea
# Processing Reccord 9 of Set 11 | bone
# Processing Reccord 10 of Set 11 | dourbali
# Processing Reccord 11 of Set 11 | luderitz
# Processing Reccord 12 of Set 11 | zhob
# Processing Reccord 13 of Set 11 | muros
# Processing Reccord 14 of Set 11 | umm durman
# City, umm durman, NOT found. Skipping...
# Processing Reccord 15 of Set 11 | payson
# Processing Reccord 16 of Set 11 | bur gabo
# City, bur gabo, NOT found. Skipping...
# Processing Reccord 17 of Set 11 | clearwater
# Processing Reccord 18 of Set 11 | margate
# Processing Reccord 19 of Set 11 | areka
# Processing Reccord 20 of Set 11 | mandera
# Processing Reccord 21 of Set 11 | avera
# Processing Reccord 22 of Set 11 | jinchengjiang
# City, jinchengjiang, NOT found. Skipping...
# Processing Reccord 23 of Set 11 | ewa beach
# Processing Reccord 24 of Set 11 | borogontsy
# Processing Reccord 25 of Set 11 | shetpe
# Processing Reccord 26 of Set 11 | purbalingga
# Processing Reccord 27 of Set 11 | hualmay
# Processing Reccord 28 of Set 11 | savannah bight
# Processing Reccord 29 of Set 11 | priboj
# Processing Reccord 30 of Set 11 | suluova
# Processing Reccord 31 of Set 11 | thunder bay
# Processing Reccord 32 of Set 11 | nuevo progreso
# Processing Reccord 33 of Set 11 | pahrump
# Processing Reccord 34 of Set 11 | yuzawa
# Processing Reccord 35 of Set 11 | tukrah
# Processing Reccord 36 of Set 11 | langres
# Processing Reccord 37 of Set 11 | marawi
# Processing Reccord 38 of Set 11 | chunskiy
# Processing Reccord 1 of Set 12 | urumqi
# Processing Reccord 2 of Set 12 | guerrero negro
# Processing Reccord 3 of Set 12 | zheleznodorozhnyy
# Processing Reccord 4 of Set 12 | buala
# Processing Reccord 5 of Set 12 | ahipara
# Processing Reccord 6 of Set 12 | mrkonjic grad
# Processing Reccord 7 of Set 12 | ukiah
# Processing Reccord 8 of Set 12 | platteville
# Processing Reccord 9 of Set 12 | huarmey
# Processing Reccord 10 of Set 12 | atasu
# Processing Reccord 11 of Set 12 | imeni babushkina
# Processing Reccord 12 of Set 12 | souillac
# Processing Reccord 13 of Set 12 | cassilandia
# Processing Reccord 14 of Set 12 | svetlogorsk
# Processing Reccord 15 of Set 12 | tarudant
# City, tarudant, NOT found. Skipping...
# Processing Reccord 16 of Set 12 | yerbogachen
# Processing Reccord 17 of Set 12 | obigarm
# Processing Reccord 18 of Set 12 | otjiwarongo
# Processing Reccord 19 of Set 12 | kurdzhinovo
# Processing Reccord 20 of Set 12 | pirovskoye
# Processing Reccord 21 of Set 12 | marcona
# City, marcona, NOT found. Skipping...
# Processing Reccord 22 of Set 12 | homer
# Processing Reccord 23 of Set 12 | kiama
# Processing Reccord 24 of Set 12 | san miguelito
# Processing Reccord 25 of Set 12 | nizhneangarsk
# Processing Reccord 26 of Set 12 | indianola
# Processing Reccord 27 of Set 12 | hervey bay
# Processing Reccord 28 of Set 12 | la paz
# Processing Reccord 29 of Set 12 | tabou
# Processing Reccord 30 of Set 12 | nyuksenitsa
# Processing Reccord 31 of Set 12 | tulun
# Processing Reccord 32 of Set 12 | pakhtakoron
# Processing Reccord 33 of Set 12 | umm lajj
# Processing Reccord 34 of Set 12 | san cristobal
# Processing Reccord 35 of Set 12 | camacupa
# Processing Reccord 36 of Set 12 | iranshahr
# Processing Reccord 37 of Set 12 | north myrtle beach
# Processing Reccord 38 of Set 12 | linxia
# Processing Reccord 1 of Set 13 | turukhansk
# Processing Reccord 2 of Set 13 | salalah
# Processing Reccord 3 of Set 13 | padang
# Processing Reccord 4 of Set 13 | maniitsoq
# Processing Reccord 5 of Set 13 | hilo
# Processing Reccord 6 of Set 13 | atambua
# Processing Reccord 7 of Set 13 | smithers
# Processing Reccord 8 of Set 13 | lasa
# Processing Reccord 9 of Set 13 | vanimo
# Processing Reccord 10 of Set 13 | inta
# Processing Reccord 11 of Set 13 | hamilton
# Processing Reccord 12 of Set 13 | kilrush
# Processing Reccord 13 of Set 13 | qaqortoq
# Processing Reccord 14 of Set 13 | henties bay
# Processing Reccord 15 of Set 13 | felidhoo
# City, felidhoo, NOT found. Skipping...
# Processing Reccord 16 of Set 13 | sawtell
# Processing Reccord 17 of Set 13 | west bay
# Processing Reccord 18 of Set 13 | qasigiannguit
# Processing Reccord 19 of Set 13 | horsham
# Processing Reccord 20 of Set 13 | lata
# Processing Reccord 21 of Set 13 | berdigestyakh
# Processing Reccord 22 of Set 13 | yar-sale
# Processing Reccord 23 of Set 13 | gurgan
# City, gurgan, NOT found. Skipping...
# Processing Reccord 24 of Set 13 | bushehr
# Processing Reccord 25 of Set 13 | kalemie
# Processing Reccord 26 of Set 13 | yuzhno-sukhokumsk
# Processing Reccord 27 of Set 13 | siavonga
# Processing Reccord 28 of Set 13 | klyuchi
# Processing Reccord 29 of Set 13 | kalulushi
# Processing Reccord 30 of Set 13 | bulgan
# Processing Reccord 31 of Set 13 | louisbourg
# City, louisbourg, NOT found. Skipping...
# Processing Reccord 32 of Set 13 | fernley
# Processing Reccord 33 of Set 13 | dombas
# Processing Reccord 34 of Set 13 | cruz alta
# Processing Reccord 35 of Set 13 | nouadhibou
# Processing Reccord 36 of Set 13 | khani
# Processing Reccord 37 of Set 13 | shashi
# Processing Reccord 38 of Set 13 | ilam
# Processing Reccord 1 of Set 14 | leshukonskoye
# Processing Reccord 2 of Set 14 | camacha
# Processing Reccord 3 of Set 14 | beringovskiy
# Processing Reccord 4 of Set 14 | okato
# Processing Reccord 5 of Set 14 | lavrentiya
# Processing Reccord 6 of Set 14 | yarada
# Processing Reccord 7 of Set 14 | bilma
# Processing Reccord 8 of Set 14 | ardakan
# Processing Reccord 9 of Set 14 | khasan
# Processing Reccord 10 of Set 14 | ulaanbaatar
# Processing Reccord 11 of Set 14 | udachnyy
# Processing Reccord 12 of Set 14 | sakakah
# Processing Reccord 13 of Set 14 | gizo
# Processing Reccord 14 of Set 14 | alyangula
# Processing Reccord 15 of Set 14 | saint-paul
# Processing Reccord 16 of Set 14 | misratah
# Processing Reccord 17 of Set 14 | husavik
# Processing Reccord 18 of Set 14 | malakal
# Processing Reccord 19 of Set 14 | tocache
# Processing Reccord 20 of Set 14 | yar
# Processing Reccord 21 of Set 14 | emerald
# Processing Reccord 22 of Set 14 | rivers
# Processing Reccord 23 of Set 14 | sao geraldo do araguaia
# Processing Reccord 24 of Set 14 | naze
# Processing Reccord 25 of Set 14 | nadym
# Processing Reccord 26 of Set 14 | sao joao da barra
# Processing Reccord 27 of Set 14 | agadez
# Processing Reccord 28 of Set 14 | ulladulla
# Processing Reccord 29 of Set 14 | nenjiang
# Processing Reccord 30 of Set 14 | rosport
# Processing Reccord 31 of Set 14 | bantou
# Processing Reccord 32 of Set 14 | sambava
# Processing Reccord 33 of Set 14 | kuche
# City, kuche, NOT found. Skipping...
# Processing Reccord 34 of Set 14 | luang prabang
# Processing Reccord 35 of Set 14 | preobrazheniye
# Processing Reccord 36 of Set 14 | ust-kuyga
# Processing Reccord 37 of Set 14 | college
# Processing Reccord 38 of Set 14 | santiago
# Processing Reccord 1 of Set 15 | pila
# Processing Reccord 2 of Set 15 | tateyama
# Processing Reccord 3 of Set 15 | jacqueville
# Processing Reccord 4 of Set 15 | phangnga
# Processing Reccord 5 of Set 15 | adre
# Processing Reccord 6 of Set 15 | kisangani
# Processing Reccord 7 of Set 15 | petropavlovsk-kamchatskiy
# Processing Reccord 8 of Set 15 | liverpool
# Processing Reccord 9 of Set 15 | tagusao
# Processing Reccord 10 of Set 15 | sakaraha
# Processing Reccord 11 of Set 15 | aksarka
# Processing Reccord 12 of Set 15 | belyy yar
# Processing Reccord 13 of Set 15 | talcahuano
# Processing Reccord 14 of Set 15 | koltubanovskiy
# Processing Reccord 15 of Set 15 | shimoda
# Processing Reccord 16 of Set 15 | miraflores
# Processing Reccord 17 of Set 15 | jishou
# Processing Reccord 18 of Set 15 | qinhuangdao
# Processing Reccord 19 of Set 15 | mergui
# City, mergui, NOT found. Skipping...
# Processing Reccord 20 of Set 15 | chalmette
# Processing Reccord 21 of Set 15 | deputatskiy
# Processing Reccord 22 of Set 15 | prince albert
# Processing Reccord 23 of Set 15 | cockburn town
# Processing Reccord 24 of Set 15 | coahuayana
# Processing Reccord 25 of Set 15 | kirovskiy
# Processing Reccord 26 of Set 15 | uinskoye
# Processing Reccord 27 of Set 15 | progreso
# Processing Reccord 28 of Set 15 | monte alegre
# Processing Reccord 29 of Set 15 | the valley
# Processing Reccord 30 of Set 15 | yelniki
# Processing Reccord 31 of Set 15 | malwan
# City, malwan, NOT found. Skipping...
# Processing Reccord 32 of Set 15 | vihti
# Processing Reccord 33 of Set 15 | sawakin
# Processing Reccord 34 of Set 15 | nuuk
# Processing Reccord 35 of Set 15 | bac can
# City, bac can, NOT found. Skipping...
# Processing Reccord 36 of Set 15 | bratsk
# Processing Reccord 37 of Set 15 | acapulco
# Processing Reccord 38 of Set 15 | sola
# Processing Reccord 1 of Set 16 | daoukro
# Processing Reccord 2 of Set 16 | swan hill
# Processing Reccord 3 of Set 16 | santa cruz del norte
# Processing Reccord 4 of Set 16 | bilibino
# Processing Reccord 5 of Set 16 | birao
# Processing Reccord 6 of Set 16 | bali
# Processing Reccord 7 of Set 16 | daru
# Processing Reccord 8 of Set 16 | cazaje
# City, cazaje, NOT found. Skipping...
# Processing Reccord 9 of Set 16 | tahoua
# Processing Reccord 10 of Set 16 | bubaque
# Processing Reccord 11 of Set 16 | saint-georges
# Processing Reccord 12 of Set 16 | lamu
# Processing Reccord 13 of Set 16 | te anau
# Processing Reccord 14 of Set 16 | chagda
# City, chagda, NOT found. Skipping...
# Processing Reccord 15 of Set 16 | kamaishi
# Processing Reccord 16 of Set 16 | saint combs
# City, saint combs, NOT found. Skipping...
# Processing Reccord 17 of Set 16 | tottori
# Processing Reccord 18 of Set 16 | tororo
# Processing Reccord 19 of Set 16 | rabo de peixe
# Processing Reccord 20 of Set 16 | ostersund
# Processing Reccord 21 of Set 16 | karpathos
# Processing Reccord 22 of Set 16 | alamosa
# Processing Reccord 23 of Set 16 | chiredzi
# Processing Reccord 24 of Set 16 | alcacer do sal
# Processing Reccord 25 of Set 16 | vozrozhdeniye
# Processing Reccord 26 of Set 16 | tutoia
# Processing Reccord 27 of Set 16 | xinzhou
# Processing Reccord 28 of Set 16 | nizhneyansk
# City, nizhneyansk, NOT found. Skipping...
# Processing Reccord 29 of Set 16 | gudari
# Processing Reccord 30 of Set 16 | kholtoson
# Processing Reccord 31 of Set 16 | san policarpo
# Processing Reccord 32 of Set 16 | mercaderes
# Processing Reccord 33 of Set 16 | kampot
# Processing Reccord 34 of Set 16 | bosaso
# Processing Reccord 35 of Set 16 | tehachapi
# Processing Reccord 36 of Set 16 | luneburg
# Processing Reccord 37 of Set 16 | barstow
# Processing Reccord 38 of Set 16 | sheridan
# Processing Reccord 1 of Set 17 | ribeira brava
# Processing Reccord 2 of Set 17 | aykhal
# Processing Reccord 3 of Set 17 | ust-nera
# Processing Reccord 4 of Set 17 | wangkui
# Processing Reccord 5 of Set 17 | dois vizinhos
# Processing Reccord 6 of Set 17 | jam sahib
# Processing Reccord 7 of Set 17 | cairns
# Processing Reccord 8 of Set 17 | verkhoyansk
# Processing Reccord 9 of Set 17 | ketchikan
# Processing Reccord 10 of Set 17 | mount gambier
# Processing Reccord 11 of Set 17 | puerto ayacucho
# Processing Reccord 12 of Set 17 | fairbanks
# Processing Reccord 13 of Set 17 | mehamn
# Processing Reccord 14 of Set 17 | burica
# City, burica, NOT found. Skipping...
# Processing Reccord 15 of Set 17 | ust-omchug
# Processing Reccord 16 of Set 17 | los llanos de aridane
# Processing Reccord 17 of Set 17 | adrar
# Processing Reccord 18 of Set 17 | krechevitsy
# Processing Reccord 19 of Set 17 | soria
# Processing Reccord 20 of Set 17 | kaspiysk
# Processing Reccord 21 of Set 17 | boralday
# Processing Reccord 22 of Set 17 | kitimat
# Processing Reccord 23 of Set 17 | kifri
# Processing Reccord 24 of Set 17 | ouadda
# Processing Reccord 25 of Set 17 | mantua
# Processing Reccord 26 of Set 17 | paulo afonso
# Processing Reccord 27 of Set 17 | borba
# Processing Reccord 28 of Set 17 | killin
# Processing Reccord 29 of Set 17 | honningsvag
# Processing Reccord 30 of Set 17 | bay city
# Processing Reccord 31 of Set 17 | ambilobe
# Processing Reccord 32 of Set 17 | brae
# Processing Reccord 33 of Set 17 | sechura
# Processing Reccord 34 of Set 17 | neuquen
# Processing Reccord 35 of Set 17 | bonthe
# Processing Reccord 36 of Set 17 | tezu
# Processing Reccord 37 of Set 17 | wanaka
# -----------------------------
# Data Retrieval Complete.
# Found 595Records from 645 cities.
# 50 cities not found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cityData_df = pd.DataFrame(columns = ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 
                                      'Country', 'Date'])
dfCount = 0
for data in cityData:
    dfCount = dfCount + 1
    curCityInfo = {
        "City" : data['name'],
        "Lat" : data['coord']['lat'],
        "Lng" : data['coord']['lon'],
        "Max Temp" : round(data['main']['temp_max'], 2),
        "Humidity" : data['main']['humidity'],
        "Cloudiness" : data['clouds']['all'],
        "Wind Speed" : data['wind']['speed'],
        "Country" : data['sys']['country'],
        "Date" : data['dt']
    }
    
    cityData_df = cityData_df.append(curCityInfo, ignore_index = True)
cityData_df = cityData_df.rename_axis('City_ID')
cityData_df.head()
# Out:
#                          City      Lat       Lng  Max Temp Humidity  \
# City_ID
# 0                        Soyo  -6.1349   12.3689    297.89       81
# 1              Ribeira Grande  38.5167  -28.7000    293.37       73
# 2                 Provideniya  64.3833 -173.3000    266.21       63
# 3                 Hvolsvollur  63.7533  -20.2243    276.38       77
# 4        Vila Franca do Campo  37.7167  -25.4333    292.38       90
#
#         Cloudiness  Wind Speed Country        Date
# City_ID
# 0               93        2.14      AO  1635364128
# 1               20        7.20      PT  1635364128
# 2               75        5.00      RU  1635364128
# 3               99        2.54      IS  1635364129
# 4              100        4.05      PT  1635364129

# %%
cityData_csv = cityData_df.to_csv(output_data_file, index_label = 'City_ID')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cityData_df.loc[cityData_df['Humidity'] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.figure(1)
plt.scatter(cityData_df['Lat'], cityData_df['Max Temp'])
plt.title(f'Latitude vs. Temperature ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.savefig('../output_data/Fig1.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(2)
plt.scatter(cityData_df['Lat'], cityData_df['Humidity'])
plt.title(f'Latitude vs. Humidity ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('../output_data/Fig2.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(3)
plt.scatter(cityData_df['Lat'], cityData_df['Cloudiness'])
plt.title(f'Latitude vs. Cloudiness ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('../output_data/Fig3.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(4)
plt.scatter(cityData_df['Lat'], cityData_df['Wind Speed'])
plt.title(f'Latitude vs. Wind Speed ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('../output_data/Fig4.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
f1x_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Lat']
f1y_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Max Temp']
(f1slope, f1intercept, f1rvalue, f1pvalue, f1stderr) = linregress(f1x_values, f1y_values)
f1regress_values = f1x_values * f1slope + f1intercept
f1line_eq = "y = " + str(round(f1slope,2)) + "x + " + str(round(f1intercept,2))
plt.scatter(f1x_values,f1y_values)
plt.plot(f1x_values,f1regress_values,"r-")
plt.annotate(f1line_eq,(0,250),fontsize=15,color="red")
plt.title(f'Northern Hemisphere Latitude vs. Temperature ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {f1rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7630059602058381

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
f1ax_values = cityData_df.loc[cityData_df['Lat'] < 0]['Lat']
f1ay_values = cityData_df.loc[cityData_df['Lat'] < 0]['Max Temp']
(f1aslope, f1aintercept, f1arvalue, f1apvalue, f1astderr) = linregress(f1ax_values, f1ay_values)
f1aregress_values = f1ax_values * f1aslope + f1aintercept
f1aline_eq = "y = " + str(round(f1aslope,2)) + "x + " + str(round(f1aintercept,2))
plt.scatter(f1ax_values,f1ay_values)
plt.plot(f1ax_values,f1aregress_values,"r-")
plt.annotate(f1aline_eq,(-55,305),fontsize=15,color="red")
plt.title(f'Southern Hemisphere Latitude vs. Temperature ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {f1arvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.29430218773712086

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
f2x_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Lat']
f2y_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Humidity'].astype('float64')
(f2slope, f2intercept, f2rvalue, f2pvalue, f2stderr) = linregress(f2x_values, f2y_values)
f2regress_values = f2x_values * f2slope + f2intercept
f2line_eq = "y = " + str(round(f2slope,2)) + "x + " + str(round(f2intercept,2))
plt.scatter(f2x_values,f2y_values)
plt.plot(f2x_values,f2regress_values,"r-")
plt.annotate(f2line_eq,(0,10),fontsize=15,color="red")
plt.title(f'Northern Hemisphere Latitude vs. Humidity ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {f2rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08937596454308569

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
f2ax_values = cityData_df.loc[cityData_df['Lat'] < 0]['Lat']
f2ay_values = cityData_df.loc[cityData_df['Lat'] < 0]['Humidity'].astype('float64')
(f2aslope, f2aintercept, f2arvalue, f2apvalue, f2astderr) = linregress(f2ax_values, f2ay_values)
f2aregress_values = f2ax_values * f2aslope + f2aintercept
f2aline_eq = "y = " + str(round(f2aslope,2)) + "x + " + str(round(f2aintercept,2))
plt.scatter(f2ax_values,f2ay_values)
plt.plot(f2ax_values,f2aregress_values,"r-")
plt.annotate(f2aline_eq,(-50,10),fontsize=15,color="red")
plt.title(f'Southern Hemisphere Latitude vs. Humidity ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {f2arvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04567084388674402

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
f3x_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Lat']
f3y_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Cloudiness'].astype('float64')
(f3slope, f3intercept, f3rvalue, f3pvalue, f3stderr) = linregress(f3x_values, f3y_values)
f3regress_values = f3x_values * f3slope + f3intercept
f3line_eq = "y = " + str(round(f3slope,2)) + "x + " + str(round(f3intercept,2))
plt.scatter(f3x_values,f3y_values)
plt.plot(f3x_values,f3regress_values,"r-")
plt.annotate(f3line_eq,(0,10),fontsize=15,color="red")
plt.title(f'Northern Hemisphere Latitude vs. Cloudiness ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {f3rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.024425341915402056

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
f3ax_values = cityData_df.loc[cityData_df['Lat'] < 0]['Lat']
f3ay_values = cityData_df.loc[cityData_df['Lat'] < 0]['Cloudiness'].astype('float64')
(f3aslope, f3aintercept, f3arvalue, f3apvalue, f3astderr) = linregress(f3ax_values, f3ay_values)
f3aregress_values = f3ax_values * f3aslope + f3aintercept
f3aline_eq = "y = " + str(round(f3aslope,2)) + "x + " + str(round(f3aintercept,2))
plt.scatter(f3ax_values,f3ay_values)
plt.plot(f3ax_values,f3aregress_values,"r-")
plt.annotate(f3aline_eq,(-55,25),fontsize=15,color="red")
plt.title(f'Southern Hemisphere Latitude vs. Cloudiness ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {f3arvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.029958674553318826

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
f4x_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Lat']
f4y_values = cityData_df.loc[cityData_df['Lat'] >= 0]['Wind Speed']
(f4slope, f4intercept, f4rvalue, f4pvalue, f4stderr) = linregress(f4x_values, f4y_values)
f4regress_values = f4x_values * f4slope + f4intercept
f4line_eq = "y = " + str(round(f4slope,2)) + "x + " + str(round(f4intercept,2))
plt.scatter(f4x_values,f4y_values)
plt.plot(f4x_values,f4regress_values,"r-")
plt.annotate(f4line_eq,(0,10),fontsize=15,color="red")
plt.title(f'Northern Hemisphere Latitude vs. Wind Speed ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {f4rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02308122707313015

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
f4ax_values = cityData_df.loc[cityData_df['Lat'] < 0]['Lat']
f4ay_values = cityData_df.loc[cityData_df['Lat'] < 0]['Wind Speed']
(f4aslope, f4aintercept, f4arvalue, f4apvalue, f4astderr) = linregress(f4ax_values, f4ay_values)
f4aregress_values = f4ax_values * f4aslope + f4aintercept
f4aline_eq = "y = " + str(round(f4aslope,2)) + "x + " + str(round(f4aintercept,2))
plt.scatter(f4ax_values,f4ay_values)
plt.plot(f4ax_values,f4aregress_values,"r-")
plt.annotate(f4aline_eq,(-50,11),fontsize=15,color="red")
plt.title(f'Southern Hemisphere Latitude vs. Wind Speed ({date.today().strftime("%m/%d/%Y")})')
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {f4arvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08584425395090434
